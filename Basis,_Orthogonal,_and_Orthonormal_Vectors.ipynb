# %% [markdown]
# 1. buat vector i dengan elemen (1,0) dan vector j dengan elemen (0,1)

# %%
import numpy as np

# %%
# buat vector i dengan elemen (1,0) dan vector j dengan elemen (0,1)
i = np.array([1, 0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0, 1])
j
# Out:
# array([0, 1])

# %%
# buktikan bahwa vector i dan vector j itu orthogonal
np.dot(i, j)
# Out:
# np.int64(0)

# %% [markdown]
# 2. Bagaimana dengan v=(1,2) dan w=(2,-1), apakah juga orthogonal?

# %%
i = np.array([1, 2])
i
# Out:
# array([1, 2])

# %%
j = np.array([2, -1])
j
# Out:
# array([ 2, -1])

# %%
np.dot(i, j)
# Out:
# np.int64(0)
