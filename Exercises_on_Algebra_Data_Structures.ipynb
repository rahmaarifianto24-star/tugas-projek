# %% [markdown]
# 1 selesaikan soal berikut

# %%
import numpy as np

# %%
x = np.array([[25],
              [2],
              [-2],
              [-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -2],
#        [-23]])

# %%
x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -2, -23]])
